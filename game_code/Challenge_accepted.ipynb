# %%
def challenge_accpeted(play1, play2, play3): #what are the possible plays of computer
    plays = [1:10]
    player1 = play 

    #creating a random play from plays for player 2 
    import random as rd
    player
    player2 = rd.choice(plays)

    #criterion for winning the game:
# Out:
# Hello
